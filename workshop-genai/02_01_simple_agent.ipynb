# %% [markdown]
# # Simple LangChain Agent
#
# The program is a simple LangChain agent that uses Neo4j.
#
# The code:
#
# - Creates an `OpenAI` LLM `model`
# - Connects to your Neo4j database
# - Defines a `Get-graph-database-schema` tool
# - Creates a `react` (Reasoning and Acting) agent using the `model` and `tools`
# - Streams the agent's response
#
# Review and run the code and answer the following questions:
#
# 1. What is the agent's function?
# 2. What can it do?
# 3. How could you extend it?
#
# ***

# %% [markdown]
# Load the environment variables and import the required Python modules.

# %%
import os
from dotenv import load_dotenv
load_dotenv()

from langchain.chat_models import init_chat_model
from langchain.agents import create_agent
from langchain_core.tools import tool
from langchain_neo4j import Neo4jGraph

# %% [markdown]
# Create a `gpt-4o` LLM `model` and connect to your Neo4j `graph` database.

# %%
# Initialize the LLM
model = init_chat_model("gpt-4o", model_provider="openai")

# Connect to Neo4j
graph = Neo4jGraph(
    url=os.getenv("NEO4J_URI"),
    username=os.getenv("NEO4J_USERNAME"), 
    password=os.getenv("NEO4J_PASSWORD"),
)

# %% [markdown]
# Create the `tools` your agent will use.

# %%
# Define functions for each tool in the agent

@tool("Get-graph-database-schema")
def get_schema():
    """Get the schema of the graph database."""
    context = graph.schema
    return context

# Define a list of tools for the agent
tools = [get_schema]

# %% [markdown]
# > The agent will use the tool's name (`Get-graph-database-schema`), and docstring (`Get the schema of the graph database.`) to determine whether it should execute the tool to resolve a user's query.
#
# ***

# %% [markdown]
# Create the agent using the LLM `model` and `tools`.

# %%
agent = create_agent(
    model=model, 
    tools=tools
)
# Out:
# /var/folders/4b/vv8614zs40g1zqck3wptg1d00000gp/T/ipykernel_67023/3197279389.py:1: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   agent = create_react_agent(

# %% [markdown]
# Create a query for the agent, pass it to the agent, and stream the messages created by the agent.
#
# When you run the agent, you will see:
#
# 1. The messages between `Human`, `AI`, and `Tool`
# 2. The context of the database schema
# 3. The agent's final response

# %%
# Run the application
query = "Summarise the schema of the graph database."

for step in agent.stream(
    {
        "messages": [{"role": "user", "content": query}]
    },
    stream_mode="values",
):
    step["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Summarise the schema of the graph database.
# ================================== Ai Message ==================================
# Tool Calls:
#   Get-graph-database-schema (call_TSNAoh1wZfufni8MHH2bHtsX)
#  Call ID: call_TSNAoh1wZfufni8MHH2bHtsX
#   Args:
# ================================= Tool Message =================================
# Name: Get-graph-database-schema
#
# Node properties:
# Document {path: STRING, createdAt: STRING, document_type: STRING}
# Chunk {index: INTEGER, text: STRING, embedding: LIST}
# Company {name: STRING, ticker: STRING}
# Product {name: STRING}
# Executive {name: STRING}
# RiskFactor {name: STRING}
# FinancialMetric {name: STRING}
# Transaction {name: STRING}
# StockType {name: STRING}
# TimePeriod {name: STRING}
# AssetManager {managerName: STRING, managerCik: INTEGER}
# Relationship properties:
# HAS_METRIC {2023: STRING, 2022: STRING, 2021: STRING, estimated_increase: STRING, 2022_value: STRING, change_percentage: STRING, percentage_of_total_net_sales: STRING, 2021_value: STRING, statutory_federal_income_tax_rate: STRING, effective_tax_rate: STRING, 2023_value: STRING, amount: STRING, entity: STRING, type: STRING, year: STRING, time_period: STRING}
# OWNS {position_status: STRING, Value: FLOAT, shares: INTEGER, share_value: FLOAT}
# The relationships:
# (:Chunk)-[:FROM_DOCUMENT]->(:Document)
# (:Chunk)-[:NEXT_CHUNK]->(:Chunk)
# (:Company)-[:MENTIONS]->(:Product)
# (:Company)-[:FROM_CHUNK]->(:Chunk)
# (:Company)-[:FACES_RISK]->(:RiskFactor)
# (:Company)-[:HAS_METRIC]->(:FinancialMetric)
# (:Company)-[:ISSUED_STOCK]->(:StockType)
# (:Company)-[:FILED]->(:Document)
# (:Product)-[:FROM_CHUNK]->(:Chunk)
# (:Executive)-[:FROM_CHUNK]->(:Chunk)
# (:RiskFactor)-[:FROM_CHUNK]->(:Chunk)
# (:FinancialMetric)-[:FROM_CHUNK]->(:Chunk)
# (:Transaction)-[:FROM_CHUNK]->(:Chunk)
# (:StockType)-[:FROM_CHUNK]->(:Chunk)
# (:TimePeriod)-[:FROM_CHUNK]->(:Chunk)
# (:AssetManager)-[:OWNS]->(:Company)
# ================================== Ai Message ==================================
#
# The schema of the graph database includes various types of nodes and relationships:
#
# ### Node Properties
# 1. **Document**:
#    - Properties: path (STRING), createdAt (STRING), document_type (STRING)
#
# 2. **Chunk**:
#    - Properties: index (INTEGER), text (STRING), embedding (LIST)
#
# 3. **Company**:
#    - Properties: name (STRING), ticker (STRING)
#
# 4. **Product**:
#    - Properties: name (STRING)
#
# 5. **Executive**:
#    - Properties: name (STRING)
#
# 6. **RiskFactor**:
#    - Properties: name (STRING)
#
# 7. **FinancialMetric**:
#    - Properties: name (STRING)
#
# 8. **Transaction**:
#    - Properties: name (STRING)
#
# 9. **StockType**:
#    - Properties: name (STRING)
#
# 10. **TimePeriod**:
#     - Properties: name (STRING)
#
# 11. **AssetManager**:
#     - Properties: managerName (STRING), managerCik (INTEGER)
#
# ### Relationship Properties
# - **HAS_METRIC**: Contains various properties like values for different years, estimated increase, change percentage, tax rates, etc.
# - **OWNS**: Contains properties such as position_status (STRING), Value (FLOAT), shares (INTEGER), and share_value (FLOAT).
#
# ### Relationships
# 1. **Chunk** relationships:
#    - FROM_DOCUMENT: Connects a Chunk to a Document.
#    - NEXT_CHUNK: Connects one Chunk to another, specifying the sequence.
#
# 2. **Company** relationships:
#    - MENTIONS: Connects a Company to a Product.
#    - FROM_CHUNK: Connects a Company to a Chunk.
#    - FACES_RISK: Connects a Company to a RiskFactor.
#    - HAS_METRIC: Connects a Company to a FinancialMetric.
#    - ISSUED_STOCK: Connects a Company to a StockType.
#    - FILED: Connects a Company to a Document.
#
# 3. Other relationships such as:
#    - FROM_CHUNK: Connects Products, Executives, RiskFactors, FinancialMetrics, Transactions, StockTypes, and TimePeriods to Chunks.
#    - OWNS: Connects an AssetManager to a Company.
#
# These nodes and relationships form the basis for capturing the entities and their interactions within the graph database.

# %% [markdown]
# Experiment with agent, modify the `query` to ask different questions, for example:
#
# * `"How are Products related to other entities?"`
# * `"What questions can I answer using this graph database?"`
# * `"How does the graph model relate financial documents to risk factors?"`
#
# ***
#
# [View the complete code](solutions/02_01_simple_agent.py)
